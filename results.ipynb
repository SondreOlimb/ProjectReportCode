# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; 
from matplotlib.colors import LogNorm, Normalize
from scipy.signal import butter, lfilter, freqz,detrend
from scipy import signal
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np
from scipy import constants
#sns.set_theme()
import re
import utils
from scipy import ndimage
from scipy.signal import lfilter
from scipy.ndimage.filters import gaussian_filter
import cv2

# %%
#Record_2022-09-27_14-14-14.bin
no_reflector = "felttest1/Record_2022-09-27_14-34-48/Record_2022-09-27_14-34-48.bin"
best_restult = "felttest1/Record_2022-09-27_14-14-14/Record_2022-09-27_14-14-14.bin"
munkholm = "felttest2/Record_2022-09-28_15-13-15/Record_2022-09-28_15-13-15.bin"
try:
    #with open("felttest2/Record_2022-09-28_14-48-46/Record_2022-09-28_14-48-46.bin", "rb") as f:
    #with open("Record_2022-09-28_15-13-15.bin", "rb") as f:
    with open(best_restult, "rb") as f:

        data = f.read()
    
        
        
except IOError as e:
    print(e)

# %%
stri = "DONE"
done = False
data_arr = []
index = 0
data_bytes = data
while(not done):
    ls = re.search(stri.encode(), data_bytes).end()
    data_arr.append(data_bytes[:ls])
    data_bytes = data_bytes[ls+4:]
    print(len(data_bytes))
    if(len(data_bytes) == 0):
        done = True
# Out:
# 725850672
# 724801916
# 723753136
# 722704392
# 721655612
# 720606868
# 719558112
# 718509392
# 717460660
# 716411904
# 715363148
# 714314380
# 713265588
# 712216796
# 711168028
# 710119236
# 709070456
# 708021664
# 706972884
# 705924116
# 704875336
# 703826556
# 702777764
# 701728996
# 700680192
# 699631364
# 698582548
# 697533708
# 696484880
# 695436064
# 694387248
# 693338480
# 692289712
# 691240944
# 690192152
# 689143360
# 688094604
# 687045860
# 685997104
# 684948312
# 683899532
# 682850776
# 681802008
# 680753264
# 679704520
# 678655776
# 677606960
# 676558156
# 675509412
# 674460620
# 673411828
# 672363072
# 671314304
# 670265548
# 669216780
# 668168012
# 667119232
# 666070428
# 665021624
# 663972784
# 662923992
# 661875224
# 660826396
# 659777604
# 658728824
# 657680056
# 656631300
# 655582532
# 654533752
# 653484972
# 652436204
# 651387424
# 650338680
# 649289924
# 648241156
# 647192424
# 646143668
# 645094900
# 644046132
# 642997328
# 641948536
# 640899756
# 639850940
# 638802148
# 637753368
# 636704552
# 635655748
# 634606992
# 633558212
# 632509384
# 631460580
# 630411788
# 629362984
# 628314180
# 627265352
# 626216560
# 625167780
# 624118940
# 623070116
# 622021256
# 620972408
# 619923548
# 618874676
# 617825780
# 616776896
# 615728060
# 614679200
# 613630376
# 612581516
# 611532656
# 610483808
# 609434960
# 608386088
# 607337228
# 606288344
# 605239484
# 604190672
# 603141872
# 602093000
# 601044140
# 599995292
# 598946444
# 597897596
# 596848760
# 595799936
# 594751136
# 593702312
# 592653488
# 591604676
# 590555816
# 589507004
# 588458156
# 587409332
# 586360508
# 585311672
# 584262824
# 583214000
# 582165140
# 581116268
# 580067432
# 579018596
# 577969748
# 576920936
# 575872100
# 574823240
# 573774368
# 572725544
# 571676660
# 570627812
# 569578952
# 568530104
# 567481268
# 566432432
# 565383584
# 564334748
# 563285936
# 562237088
# 561188216
# 560139368
# 559090496
# 558041648
# 556992728
# 555943832
# 554894996
# 553846136
# 552797228
# 551748280
# 550699296
# 549650324
# 548601340
# 547552380
# 546503408
# 545454472
# 544405560
# 543356636
# 542307712
# 541258752
# 540209804
# 539160880
# 538111920
# 537062972
# 536014048
# 534965168
# 533916312
# 532867432
# 531818552
# 530769684
# 529720852
# 528672008
# 527623152
# 526574260
# 525525436
# 524476620
# 523427768
# 522378976
# 521330148
# 520281320
# 519232492
# 518183652
# 517134776
# 516085912
# 515037084
# 513988232
# 512939416
# 511890612
# 510841740
# 509792928
# 508744044
# 507695148
# 506646300
# 505597428
# 504548532
# 503499636
# 502450740
# 501401880
# 500352984
# 499303984
# 498255068
# 497206140
# 496157212
# 495108368
# 494059476
# 493010572
# 491961668
# 490912752
# 489863836
# 488814992
# 487766144
# 486717332
# 485668484
# 484619672
# 483570800
# 482521928
# 481473080
# 480424220
# 479375348
# 478326500
# 477277628
# 476228804
# 475179980
# 474131132
# 473082272
# 472033412
# 470984552
# 469935692
# 468886772
# 467837900
# 466789052
# 465740180
# 464691332
# 463642472
# 462593624
# 461544800
# 460495952
# 459447036
# 458398084
# 457349144
# 456300204
# 455251300
# 454202328
# 453153392
# 452104468
# 451055532
# 450006596
# 448957696
# 447908760
# 446859824
# 445810912
# 444761988
# 443713088
# 442664176
# 441615252
# 440566292
# 439517296
# 438468348
# 437419352
# 436370404
# 435321420
# 434272472
# 433223500
# 432174548
# 431125600
# 430076616
# 429027620
# 427978660
# 426929688
# 425880692
# 424831696
# 423782700
# 422733704
# 421684744
# 420635796
# 419586824
# 418537852
# 417488856
# 416439848
# 415390876
# 414341940
# 413292992
# 412244056
# 411195120
# 410146136
# 409097164
# 408048216
# 406999280
# 405950320
# 404901348
# 403852388
# 402803416
# 401754480
# 400705472
# 399656524
# 398607600
# 397558688
# 396509764
# 395460840
# 394411880
# 393362944
# 392313972
# 391265024
# 390216108
# 389167228
# 388118276
# 387069372
# 386020468
# 384971588
# 383922616
# 382873680
# 381824768
# 380775808
# 379726836
# 378677876
# 377628948
# 376580052
# 375531144
# 374482296
# 373433380
# 372384488
# 371335572
# 370286692
# 369237764
# 368188872
# 367139944
# 366091052
# 365042160
# 363993292
# 362944424
# 361895556
# 360846664
# 359797760
# 358748820
# 357699880
# 356650988
# 355602096
# 354553216
# 353504336
# 352455384
# 351406468
# 350357588
# 349308708
# 348259792
# 347210888
# 346161972
# 345113092
# 344064212
# 343015308
# 341966392
# 340917476
# 339868596
# 338819644
# 337770668
# 336721752
# 335672744
# 334623872
# 333574992
# 332526064
# 331477100
# 330428208
# 329379244
# 328330352
# 327281448
# 326232544
# 325183592
# 324134664
# 323085736
# 322036796
# 320987832
# 319938880
# 318889940
# 317841000
# 316792120
# 315743216
# 314694228
# 313645288
# 312596324
# 311547360
# 310498396
# 309449384
# 308400412
# 307351416
# 306302420
# 305253400
# 304204416
# 303155396
# 302106400
# 301057416
# 300008420
# 298959388
# 297910452
# 296861468
# 295812460
# 294763524
# 293714552
# 292665544
# 291616560
# 290567552
# 289518580
# 288469596
# 287420576
# 286371580
# 285322584
# 284273564
# 283224548
# 282175472
# 281126408
# 280077436
# 279028408
# 277979368
# 276930292
# 275881264
# 274832224
# 273783232
# 272734272
# 271685320
# 270636392
# 269587452
# 268538536
# 267489572
# 266440620
# 265391632
# 264342668
# 263293632
# 262244692
# 261195776
# 260146836
# 259097872
# 258048864
# 256999856
# 255950872
# 254901900
# 253852880
# 252803860
# 251754876
# 250705856
# 249656812
# 248607804
# 247558808
# 246509764
# 245460652
# 244411544
# 243362424
# 242313316
# 241264276
# 240215280
# 239166260
# 238117276
# 237068304
# 236019284
# 234970252
# 233921232
# 232872164
# 231823156
# 230774184
# 229725212
# 228676240
# 227627292
# 226578320
# 225529384
# 224480412
# 223431488
# 222382588
# 221333676
# 220284740
# 219235816
# 218186912
# 217137940
# 216089060
# 215040072
# 213991168
# 212942264
# 211893396
# 210844480
# 209795588
# 208746696
# 207697756
# 206648868
# 205599944
# 204550996
# 203502024
# 202453064
# 201404092
# 200355132
# 199306180
# 198257216
# 197208276
# 196159348
# 195110432
# 194061492
# 193012564
# 191963660
# 190914720
# 189865792
# 188816900
# 187767996
# 186719128
# 185670188
# 184621212
# 183572248
# 182523332
# 181474312
# 180425384
# 179376432
# 178327480
# 177278528
# 176229588
# 175180696
# 174131804
# 173082888
# 172033984
# 170985080
# 169936152
# 168887212
# 167838320
# 166789368
# 165740452
# 164691548
# 163642596
# 162593644
# 161544660
# 160495652
# 159446692
# 158397720
# 157348760
# 156299752
# 155250804
# 154201844
# 153152920
# 152103924
# 151054952
# 150005980
# 148957008
# 147908116
# 146859156
# 145810252
# 144761268
# 143712308
# 142663360
# 141614400
# 140565392
# 139516420
# 138467388
# 137418380
# 136369384
# 135320376
# 134271392
# 133222420
# 132173508
# 131124560
# 130075612
# 129026640
# 127977704
# 126928768
# 125879784
# 124830768
# 123781776
# 122732744
# 121683808
# 120634872
# 119585912
# 118536940
# 117487992
# 116438996
# 115389976
# 114340908
# 113291888
# 112242880
# 111193908
# 110144960
# 109096000
# 108047096
# 106998216
# 105949336
# 104900420
# 103851504
# 102802564
# 101753648
# 100704708
# 99655744
# 98606852
# 97557948
# 96509056
# 95460104
# 94411176
# 93362236
# 92313284
# 91264276
# 90215304
# 89166252
# 88117244
# 87068236
# 86019228
# 84970220
# 83921260
# 82872264
# 81823292
# 80774320
# 79725292
# 78676284
# 77627184
# 76578120
# 75529032
# 74479956
# 73430888
# 72381832
# 71332836
# 70283804
# 69234820
# 68185812
# 67136760
# 66087776
# 65038840
# 63989844
# 62940744
# 61891668
# 60842536
# 59793472
# 58744408
# 57695428
# 56646376
# 55597348
# 54548344
# 53499352
# 52450348
# 51401368
# 50352352
# 49303324
# 48254296
# 47205268
# 46156180
# 45107128
# 44058076
# 43009072
# 41960008
# 40911004
# 39862024
# 38813088
# 37764120
# 36715104
# 35666112
# 34617036
# 33568032
# 32519040
# 31470036
# 30421044
# 29372072
# 28323148
# 27274156
# 26225244
# 25176296
# 24127336
# 23078352
# 22029356
# 20980408
# 19931448
# 18882428
# 17833480
# 16784496
# 15735488
# 14686432
# 13637472
# 12588500
# 11539540
# 10490556
# 9441548
# 8392516
# 7343440
# 6294388
# 5245324
# 4196248
# 3147208
# 2098192
# 1049096
# 0

# %%
def simple_exp_smooth(d,extra_periods=1,alpha=0.4):  
  #d = np.array(d)  # Transform the input into a numpy array  
  cols = len(d)  # Historical period length  
  #d = np.append(d,[np.nan]*extra_periods)  # Append np.nan into the demand array to cover future periods  
  f = np.zeros_like(d)  # Forecast array  
  f[0] = d[0]  # initialization of first forecast  
 
  # Create all the t+1 forecasts until end of historical period  
  for t in range(1,cols):  
    f[t] = alpha*d[t]+(1-alpha)*f[t-1]
  #print(f)  
  f[cols+1:] = f[t]  # Forecast for all extra periods  
  #df = pd.DataFrame.from_dict({"Demand":d,"Forecast":f})
  return f,d

# %%
c = constants.c
sample_bandwidth  = 191.0153846e6
sample_frek = 2*sample_bandwidth # sample frekuenzy
frame_rate =50*10**(-3) # frame rate
sample_per_frame = 260*257 # sample pr frame
c_t = (1/sample_bandwidth )*256 # sample period
#fs_new = 1/sample_period_new # sample frekuenzy

# %%
def background_update(frames, alpha=1/128, nr_of_ma=1,window=1):
    fft_length = 256
    MRDM =np.zeros((len(frames),fft_length,fft_length),dtype=np.complex_)
    
        
    for i,frame in enumerate(frames):
                length = int.from_bytes(
                        frame[4:8], byteorder="little", signed=False)
                
                data_RADC = frame[8:8+length]
                data_RADC = np.frombuffer(data_RADC,dtype=np.uint16)
                data_RADC = data_RADC.reshape(3,256,512)
                data_RADC_I_raw = data_RADC[:,:,::2]
                data_RADC_Q_raw = data_RADC[:,:,1::2]
                data_RADC_I = detrend(data_RADC_I_raw, axis=2)
                data_RADC_Q = detrend(data_RADC_Q_raw, axis=2)
                #window = signal.windows.chebwin(256, 100, sym=True)#signal.windows.hann(256)
                #data_RADC_I_mean = np.mean(data_RADC_I, axis=0)
                #data_RADC_Q_mean = np.mean(data_RADC_Q, axis=0)
                data_RADC_I_mean = data_RADC_I[0]
                data_RADC_Q_mean = data_RADC_Q[0]
                data_IF = window*data_RADC_I_mean[:,:] + window*1j*data_RADC_Q_mean[:,:]
            

                data_range_baseline =utils.fft_and_plot(data_IF, axis=1, fs=sample_frek,fft_size=fft_length,plot=False,shift =False)
                #data_range_baseline = utils.MIT_filter( data_range_baseline)
                for j in range(fft_length):
                    data_range_baseline[:,j] = window*data_range_baseline[:,j]
                #
                data_range_baseline = utils.MIT_filter( data_range_baseline)
                data_doppler_window_slow= utils.fft_and_plot(data_range_baseline, axis=0,fft_size=fft_length,shift =True)
                
                #MRDM[i]=cv2.GaussianBlur(np.abs(data_doppler_window_slow) ,(3, 3),sigmaX=1,sigmaY=1)
            
                MRDM[i] = data_doppler_window_slow

    #MIT
   
    #MRDM = np.mean(MRDM,axis=0)
    
    raw_frames = MRDM.copy()
    data_procesed =MRDM.copy()
  
    data_diff = MRDM.copy()
    for i in range(nr_of_ma):
            MA,frames =simple_exp_smooth(np.abs(data_diff.copy()),alpha =alpha)
            data_diff = np.abs(frames) -np.abs(MA)
            
            #ata_diff =gaussian_filter(data_diff, sigma=1,mode='constant')
            print("MA",i)
     #   data_procesed[k] = data_diff
    #data_diff = np.mean(data_procesed,axis=0)
    utils.CFAR_2D(data_diff[-1].copy(),10, 15, 0.000001,plot=False, iso_axis=True)
    return MRDM,raw_frames,data_diff

# %%
idx = 301
data_ma,raw_t,data_diff = background_update(data_arr[1:-1],nr_of_ma=
3, alpha=1/256,window=1)
# Out:
# MA 0
# MA 1
# MA 2
# traning area 2160

# %%
plot_min_range = 40
plot_max_range = 120
plot_min_doppler = 100
plot_max_doppler = 150
plot_min_3d = 80
plot_max_3d = 95

# %% [markdown]
# # Remove peaks

# %%
#remove peaks
noise = np.mean(data_diff[1,200:220,50:70])
for i,d in enumerate(data_diff):
    data_diff[i,90:94,204:207] = noise
    data_diff[i,163:170,50:54] = noise

# %%
#%matplotlib ipympl
labels = {
    "x_label":"Velocity [knots]",
    "y_label":"Range [m]",
    "title": "Radar MRDM"

}
#data_fft_plot = cv2.GaussianBlur(np.abs(data_ma), (3, 3),sigmaX=1,sigmaY=1)
#data_fft_plot = ndimage.gaussian_filter(data_fft_plot,sigma=1,mode=mode)
#sns.set(rc={'figure.figsize':(20,15)})

test = np.max(np.abs(data_diff[:500]),axis=0)
plt.figure(figsize=(10,10))
print(np.shape(test))
#test[test>40] =0
rotated_img = ndimage.rotate(test,90)
#rotated_img = np.flip(test,axis=0)
rotated_img =20*np.log10(np.abs(rotated_img)) # We rotate the image so the x axis is the velocity


#rotated_img = cv2.GaussianBlur(rotated_img, (3, 3),sigmaX=1,sigmaY=1)
#plt.imshow(rotated_img,cmap="plasma", vmin=plot_min_doppler,vmax=plot_max_doppler)
plt.imshow(rotated_img,cmap="plasma",vmin =50)
# rms = 10*np.log(np.sqrt(np.mean(np.abs(rotated_img[130:135,80:100])**2)))
# peak = 10*np.log(np.abs(rotated_img[137,87]))
# snr = peak-rms
# print("Peak:",peak)
# print("Side loab:", 10*np.log(np.abs(rotated_img[137,85])))
# print("RMS:",rms)
# print("SNR:",snr) 
#plt.xlim(80,94)
plt.yticks(np.linspace(0,256,9),labels=np.round(np.linspace(255*0.785277,0,9)),size =15)



plt.xticks(np.linspace(0,256,7),labels=np.round(np.linspace(-0.127552440715*127,0.127552440715*127,7),2),size =15)
cbar  = plt.colorbar()
cbar.set_label('Mangnitude [dB]',fontdict = {'fontsize' : 20})
cbar.ax.tick_params(labelsize=15) 
plt.xlabel(labels["x_label"],fontdict = {'fontsize' : 20})
plt.ylabel(labels["y_label"],fontdict = {'fontsize' : 20})
plt.title(labels["title"],fontdict = {'fontsize' : 30})
plt.grid(False)
#plt.savefig("plots/munkholm/cfar_EMA_0_MTI_munkholm_with_window.svg",format="svg")
# Out:
# (256, 256)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib ipympl

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import time

#fig=plt.figure()
#ax1=fig.add_subplot(1,1,1)

def animate(i):
    rotated_img = ndimage.rotate(data_diff[i],90)
    ax1.imshow(rotated_img,cmap="plasma", vmin=0,vmax=300000)
    ax1.set_title(f"Frame: {i}")
    ax1.set_xticks(np.linspace(0,256,11),labels=np.round(np.linspace(-0.127552440715*127,0.127552440715*127,11),2))
    ax1.set_yticks(np.linspace(0,256,9),labels=np.round(np.linspace(255*0.785277,0,9)),size =15)
    ax1.autoscale(enable=True, axis='both')

#ani = FuncAnimation(fig, animate,600 ,interval=100,cache_frame_data=False)
#plt.show()

# %%
#700:1000
cfar_array= []
SNR_array = []
SNR_D_array = []
length_data_diff = len(data_diff[100:500])
for i,img in enumerate( data_diff[100:500]):
    cfar ,y,SNR,d = utils.CFAR_2D(img,10, 15, 0.000001,plot=False, iso_axis=True)
    cfar_array.append(cfar)
    SNR_array.append(SNR)
    SNR_D_array.append(y)
    print(np.round(i/length_data_diff*100,1))
# Out:
# traning area 2160
# 0.0
# traning area 2160
# 0.2
# traning area 2160
# 0.5
# traning area 2160
# 0.8
# traning area 2160
# 1.0
# traning area 2160
# 1.2
# traning area 2160
# 1.5
# traning area 2160
# 1.8
# traning area 2160
# 2.0
# traning area 2160
# 2.2
# traning area 2160
# 2.5
# traning area 2160
# 2.8
# traning area 2160
# 3.0
# traning area 2160
# 3.2
# traning area 2160
# 3.5
# traning area 2160
# 3.8
# traning area 2160
# 4.0
# traning area 2160
# 4.2
# traning area 2160
# 4.5
# traning area 2160
# 4.8
# traning area 2160
# 5.0
# traning area 2160
# 5.2
# traning area 2160
# 5.5
# traning area 2160
# 5.8
# traning area 2160
# 6.0
# traning area 2160
# 6.2
# traning area 2160
# 6.5
# traning area 2160
# 6.8
# traning area 2160
# 7.0
# traning area 2160
# 7.2
# traning area 2160
# 7.5
# traning area 2160
# 7.8
# traning area 2160
# 8.0
# traning area 2160
# 8.2
# traning area 2160
# 8.5
# traning area 2160
# 8.8
# traning area 2160
# 9.0
# traning area 2160
# 9.2
# traning area 2160
# 9.5
# traning area 2160
# 9.8
# traning area 2160
# 10.0
# traning area 2160
# 10.2
# traning area 2160
# 10.5
# traning area 2160
# 10.8
# traning area 2160
# 11.0
# traning area 2160
# 11.2
# traning area 2160
# 11.5
# traning area 2160
# 11.8
# traning area 2160
# 12.0
# traning area 2160
# 12.2
# traning area 2160
# 12.5
# traning area 2160
# 12.8
# traning area 2160
# 13.0
# traning area 2160
# 13.2
# traning area 2160
# 13.5
# traning area 2160
# 13.8
# traning area 2160
# 14.0
# traning area 2160
# 14.2
# traning area 2160
# 14.5
# traning area 2160
# 14.8
# traning area 2160
# 15.0
# traning area 2160
# 15.2
# traning area 2160
# 15.5
# traning area 2160
# 15.8
# traning area 2160
# 16.0
# traning area 2160
# 16.2
# traning area 2160
# 16.5
# traning area 2160
# 16.8
# traning area 2160
# 17.0
# traning area 2160
# 17.2
# traning area 2160
# 17.5
# traning area 2160
# 17.8
# traning area 2160
# 18.0
# traning area 2160
# 18.2
# traning area 2160
# 18.5
# traning area 2160
# 18.8
# traning area 2160
# 19.0
# traning area 2160
# 19.2
# traning area 2160
# 19.5
# traning area 2160
# 19.8
# traning area 2160
# 20.0
# traning area 2160
# 20.2
# traning area 2160
# 20.5
# traning area 2160
# 20.8
# traning area 2160
# 21.0
# traning area 2160
# 21.2
# traning area 2160
# 21.5
# traning area 2160
# 21.8
# traning area 2160
# 22.0
# traning area 2160
# 22.2
# traning area 2160
# 22.5
# traning area 2160
# 22.8
# traning area 2160
# 23.0
# traning area 2160
# 23.2
# traning area 2160
# 23.5
# traning area 2160
# 23.8
# traning area 2160
# 24.0
# traning area 2160
# 24.2
# traning area 2160
# 24.5
# traning area 2160
# 24.8
# traning area 2160
# 25.0
# traning area 2160
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/7r/2hd4ghss0015g6g41vqt9c9w0000gn/T/ipykernel_63287/1353173160.py in <module>
#       5 length_data_diff = len(data_diff[100:500])
#       6 for i,img in enumerate( data_diff[100:500]):
# ----> 7     cfar ,y,SNR,d = utils.CFAR_2D(img,10, 15, 0.000001,plot=False, iso_axis=True)
#       8     cfar_array.append(cfar)
#       9     SNR_array.append(SNR)
#
# ~/prosjektOppgave/ProjectReportCode/utils.py in CFAR_2D(data, guard_cells, training_cells, PFA, plot, iso_axis, saveFig, filename)
#     233             SNR[i,j] = np.abs(data[i,j])/np.abs(threshold)
#     234             if(np.abs(data[i,j]) < threshold):
# --> 235                 data[i,j] = 1
#     236             else:
#     237                 SNR_detections[i,j] = np.abs(data[i,j])/np.abs(threshold)
#
# KeyboardInterrupt:

# %%
data_diff.shape
# Out:
# (691, 256, 256)

# %%
# %matplotlib ipympl
labels = {
    "x_label":"Velocity [knots]",
    "y_label":"Range [m]",
    "title": "All CFAR detections"

}
#data_fft_plot = cv2.GaussianBlur(np.abs(data_ma), (3, 3),sigmaX=1,sigmaY=1)
#data_fft_plot = ndimage.gaussian_filter(data_fft_plot,sigma=1,mode=mode)
#sns.set(rc={'figure.figsize':(20,15)})

test = np.max(np.abs(cfar_array),axis=0)
plt.figure(figsize=(10,10))
print(np.shape(test))
#test[test>40] =0

rotated_img =20*np.log10(np.abs(test)) # We rotate the image so the x axis is the velocity
#rotated_img = ndimage.rotate(rotated_img,90)
#rotated_img = cv2.GaussianBlur(rotated_img, (3, 3),sigmaX=1,sigmaY=1)
#plt.imshow(rotated_img,cmap="plasma", vmin=plot_min_doppler,vmax=plot_max_doppler)
plt.imshow(rotated_img,cmap="plasma",vmin=0)
# rms = 10*np.log(np.sqrt(np.mean(np.abs(rotated_img[130:135,80:100])**2)))
# peak = 10*np.log(np.abs(rotated_img[137,87]))
# snr = peak-rms
# print("Peak:",peak)
# print("Side loab:", 10*np.log(np.abs(rotated_img[137,85])))
# print("RMS:",rms)
# print("SNR:",snr) 
#plt.xlim(80,94)
#plt.yticks(np.linspace(0,256,9),labels=np.round(np.linspace(255*0.785277,0,9)),size =15)



#plt.xticks(np.linspace(0,256,7),labels=np.round(np.linspace(-0.127552440715*127,0.127552440715*127,7),2),size =15)
cbar  = plt.colorbar()
cbar.set_label('Mangnitude [dB]',fontdict = {'fontsize' : 20})
cbar.ax.tick_params(labelsize=15) 
plt.xlabel(labels["x_label"],fontdict = {'fontsize' : 20})
plt.ylabel(labels["y_label"],fontdict = {'fontsize' : 20})
plt.title(labels["title"],fontdict = {'fontsize' : 30})
plt.grid(False)
#plt.savefig("plots/munkholm/cfar_EMA_0_MTI_munkholm_with_window.svg",format="svg")
# Out:
# (256, 256)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
start_bin =1
end_bin = 157

detections =np.max(np.abs(SNR_D_array),axis=0)
#detections = ndimage.rotate(detections,90)
detection_line = np.abs(np.max(detections[start_bin:end_bin,86:88],axis=1))
#detection_line = np.abs(detections[start_bin:end_bin,87])

r = np.linspace((255-start_bin)*0.785277,(255-end_bin)*0.785277,len(detection_line))
print(max(detection_line))
r_squared =max(detection_line)/(r/((255-end_bin)*0.785277))**4
print(max(detection_line))
plt.plot(detection_line,label="Calculated SNR")

plt.plot(r_squared,label="Theoretical SNR decrease")

plt.legend()
plt.title("SNR vs theoretical decrease",size=25)
#plt.xticks(np.linspace(0,157,1),labels=np.round(np.linspace(-0.127552440715*127,0.127552440715*127,7),2),size=15)
plt.yticks(size=15)
plt.xlabel("range [m]",size=20)
plt.ylabel("SNR",size=20)
plt.tight_layout()
plt.xticks(np.linspace(0,len(detection_line),9),labels=np.int16(np.linspace((256-start_bin)*0.785277,(256-end_bin)*0.785277,9)),size =15)
#plt.savefig("plots/results/SNR_vs_decrese_mean.svg",format="svg")
plt.show()
# Out:
# 29.112477128081473
# 29.112477128081473
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
detections =np.mean(np.abs(raw_t[100:500]),axis=0)
detections = ndimage.rotate(detections,90)
detection_line = np.abs(detections[:157,50])



plt.plot(np.abs(detections[:157,50]),label="Doppler bin 50")
plt.plot(np.abs(detections[:157,45]),label="Doppler bin 45")
plt.plot(np.abs(detections[:157,30]),label="Doppler bin 30")



plt.legend()
plt.title("Empty Doppler bins",size=25)
#plt.xticks(np.linspace(0,157,1),labels=np.round(np.linspace(-0.127552440715*127,0.127552440715*127,7),2),size=15)
plt.yticks(size=15)
plt.xlabel("range [m]",size=20)
plt.ylabel("Magnitude",size=20)
plt.tight_layout()
plt.xticks(np.linspace(0,156,9),labels=np.int16(np.linspace(200,(255-156)*0.785277,9)),size =15)
plt.savefig("plots/noisefor_problem.svg",format="svg")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
detections =np.mean(np.abs(raw_t[100:500]),axis=0)
detections = ndimage.rotate(detections,90)
detection_line = np.abs(detections[50,])



plt.plot(np.abs(detections[50,:]),label="Doppler bin 50")
plt.plot(np.abs(detections[55,:]),label="Doppler bin 45")
plt.plot(np.abs(detections[45,:]),label="Doppler bin 30")



plt.legend()
plt.title("Empty Doppler bins",size=25)
plt.ylim(0,100000)
plt.xticks(np.linspace(0,256,7),labels=np.round(np.linspace(-0.127552440715*127,0.127552440715*127,7),2),size=15)
plt.yticks(size=15)
plt.xlabel("range [m]",size=20)
plt.ylabel("Magnitude",size=20)
plt.tight_layout()
#plt.xticks(np.linspace(0,len(detections[50,:]),9),labels=np.int16(np.linspace(200,len(detections[50,:])*0.785277,9)),size =15)
#plt.savefig("plots/noisefor_problem.svg",format="svg")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
start_bin =1
end_bin = 215

detections =np.max(np.abs(data_diff),axis=0)
detections = ndimage.rotate(detections,90)
detection_line = np.abs(np.max(detections[start_bin:end_bin,86:108],axis=1))

r = np.linspace((255-start_bin)*0.785277,(255-end_bin)*0.785277,len(detection_line))
print(max(detection_line))
r_squared =max(detection_line)/(r/((255-end_bin)*0.785277))**4
print(max(detection_line))
plt.plot(detection_line,label="Calculated SNR")

plt.plot(r_squared,label="Theoretical SNR decrease")

#plt.legend()
plt.title("Doppler bin 87: v= 5.1 kt",size=25)
#plt.xticks(np.linspace(0,157,1),labels=np.round(np.linspace(-0.127552440715*127,0.127552440715*127,7),2),size=15)
plt.yticks(size=15)
plt.xlabel("range [m]",size=20)
plt.ylabel("SNR",size=20)
plt.tight_layout()
plt.xticks(np.linspace(0,len(detection_line),9),labels=np.int16(np.linspace((256-start_bin)*0.785277,(256-end_bin)*0.785277,9)),size =15)
#plt.savefig("plots/noisefor_problem.svg",format="svg")
plt.show()
# Out:
# 694258.4059221797
# 694258.4059221797
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
data_diff_0 = data_diff.copy()

# %%
plt.figure()
start_bin =1
end_bin = 157

detections =np.max(np.abs(data_diff),axis=0)
detections  = ndimage.rotate(detections,90)
detection_line = np.abs(np.max(detections[start_bin:end_bin,86:88],axis=1))

#detections_2 =np.max(np.abs(data_diff_0),axis=0)
#detections_2  = ndimage.rotate(detections_2,90)
#detection_line_2 = np.abs(np.max(detections_2[start_bin:end_bin,50:53],axis=1))
#detection_line = np.abs(detections[start_bin:end_bin,87])

r = np.linspace((255-start_bin)*0.785277,(255-end_bin)*0.785277,len(detection_line))
print(max(detection_line))
r_squared =max(detection_line)/(r/((255-end_bin)*0.785277))**4
print(max(detection_line))
plt.semilogy(detection_line,label="5.1 kt bin")
#plt.plot(detection_line_2,label="before")
plt.semilogy(np.abs(detections[start_bin:end_bin,50]),label="Noise floor")
plt.semilogy(r_squared,label="Theoretical recived power decrease")

plt.legend()
#plt.title("Range-Doppler map",size=25)
#plt.xticks(np.linspace(0,157,1),labels=np.round(np.linspace(-0.127552440715*127,0.127552440715*127,7),2),size=15)
plt.yticks(size=15)
plt.xlabel("range [m]",size=20)
plt.ylabel("Magnitude",size=20)
plt.xlim(157,0)
plt.tight_layout()
#plt.xticks(np.linspace(0,len(detection_line),9),labels=np.int16(np.linspace((256-start_bin)*0.785277,(256-end_bin)*0.785277,9)),size =15)
plt.savefig("plots/results/recived_power_falloff_logy.png")
plt.show()
# Out:
# 3665316.809812145
# 3665316.809812145
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # MEDIAN

# %%
def P_avg(P,N):
    return P/N
def alpha(N,P_FA):
    return N*(P_FA**(-1/N)-1)

def estimated_teshold(alpha,P):
    return alpha*np.abs(P)
def window_estimator(x,training_cells,training_area):    
    
    P_total = np.sum(np.abs(x))
    P_center_square =np.sum(np.abs(x[training_cells:x.shape[0]-training_cells,training_cells:x.shape[1]-training_cells]))
    P_traning_cells = np.abs(P_total - P_center_square)
    
    return P_avg(P_total,training_area)

def CFAR_2D_Median(data, guard_cells, training_cells, PFA,plot = False,iso_axis =False,saveFig=False,filename =""):
    """_summary_

    Args:
        data (_type_): _description_
        guard_cells (_type_): _description_
        training_cells (_type_): _description_
        threshold (_type_): _description_
    """
    idx_peaks = []
    treshold_map = np.zeros(data.shape)

    window_size = guard_cells + training_cells
    data = ndimage.rotate(data, 90)
    
    data_cfar = np.pad(data, window_size, mode='edge')
    

    window_area = (2*window_size+1)**2
    training_area = window_area - (2*window_size+1-2*training_cells)**2
    print("traning area",training_area)
    a = alpha(training_area, PFA)
    detections = []

    for i in range(256):
        for j in range(256):
            P_training = window_estimator(data_cfar[i:i+2*window_size+1,j:j+2*window_size+1],training_cells ,training_area)
            threshold = estimated_teshold(a,P_training)
            treshold_map[i,j] = threshold
            
            if(np.abs(data[i,j]) < threshold):
                data[i,j] = 1
            else:
                idx_peaks.append([i,j])
                detections.append({
                    "cords":(i,j),
                    "peak":np.abs(data[i,j]),
                    "noise_est":np.abs(P_training),
                    "SNR":10*np.log10(np.abs(data[i,j])/np.abs(P_training))
                    }
                 )
                
    
    if(plot):
        newlist = sorted(detections, key=itemgetter("SNR"),reverse=True)
        print("Total detections",len(newlist))
        for i in newlist:
            print(i,"\n")
        plt.figure(figsize=(20,15))
        #rotated_img = ndimage.rotate(np.abs(data),90) # We rotate the image so the x axis is the velocity
        rotated_img =20*np.log10(np.abs(data))
        plt.imshow(rotated_img,cmap="plasma")
        plt.grid(False)
        if(iso_axis):
            plt.yticks(np.linspace(0,256,9),labels=np.linspace(200,0,9))
        
            plt.xticks(np.linspace(0,256,7),labels=np.round(np.linspace(-16.1987,16.1987,7),2))
        cbar  = plt.colorbar()
        cbar.set_label('Mangnitude [dB]',fontdict = {'fontsize' : 20})
        plt.xlabel(labels["x_label"],fontdict = {'fontsize' : 20})
        plt.ylabel(labels["y_label"],fontdict = {'fontsize' : 20})
        plt.title("CFAR",fontdict = {'fontsize' : 30})
        if saveFig:
            plt.savefig(f'plots/{filename}.svg',format="svg")
        plt.show()

        
    
    
    
            
    return data, detections, treshold_map

# %%
cfar_median= []
#SNR_array = []
#SNR_D_array = []
length_data_diff = len(data_diff[100:500])
for i,img in enumerate( data_diff[100:500]):
    cfar ,y,SNR = CFAR_2D_Median(img,5, 10, 0.000001,plot=False, iso_axis=True)
    cfar_median.append(cfar)
    #SNR_array.append(SNR)
    #SNR_D_array.append(y)
    print(np.round(i/length_data_diff*100,1))
# Out:
# traning area 840
# 0.0
# traning area 840
# 0.2
# traning area 840
# 0.5
# traning area 840
# 0.8
# traning area 840
# 1.0
# traning area 840
# 1.2
# traning area 840
# 1.5
# traning area 840
# 1.8
# traning area 840
# 2.0
# traning area 840
# 2.2
# traning area 840
# 2.5
# traning area 840
# 2.8
# traning area 840
# 3.0
# traning area 840
# 3.2
# traning area 840
# 3.5
# traning area 840
# 3.8
# traning area 840
# 4.0
# traning area 840
# 4.2
# traning area 840
# 4.5
# traning area 840
# 4.8
# traning area 840
# 5.0
# traning area 840
# 5.2
# traning area 840
# 5.5
# traning area 840
# 5.8
# traning area 840
# 6.0
# traning area 840
# 6.2
# traning area 840
# 6.5
# traning area 840
# 6.8
# traning area 840
# 7.0
# traning area 840
# 7.2
# traning area 840
# 7.5
# traning area 840
# 7.8
# traning area 840
# 8.0
# traning area 840
# 8.2
# traning area 840
# 8.5
# traning area 840
# 8.8
# traning area 840
# 9.0
# traning area 840
# 9.2
# traning area 840
# 9.5
# traning area 840
# 9.8
# traning area 840
# 10.0
# traning area 840
# 10.2
# traning area 840
# 10.5
# traning area 840
# 10.8
# traning area 840
# 11.0
# traning area 840
# 11.2
# traning area 840
# 11.5
# traning area 840
# 11.8
# traning area 840
# 12.0
# traning area 840
# 12.2
# traning area 840
# 12.5
# traning area 840
# 12.8
# traning area 840
# 13.0
# traning area 840
# 13.2
# traning area 840
# 13.5
# traning area 840
# 13.8
# traning area 840
# 14.0
# traning area 840
# 14.2
# traning area 840
# 14.5
# traning area 840
# 14.8
# traning area 840
# 15.0
# traning area 840
# 15.2
# traning area 840
# 15.5
# traning area 840
# 15.8
# traning area 840
# 16.0
# traning area 840
# 16.2
# traning area 840
# 16.5
# traning area 840
# 16.8
# traning area 840
# 17.0
# traning area 840
# 17.2
# traning area 840
# 17.5
# traning area 840
# 17.8
# traning area 840
# 18.0
# traning area 840
# 18.2
# traning area 840
# 18.5
# traning area 840
# 18.8
# traning area 840
# 19.0
# traning area 840
# 19.2
# traning area 840
# 19.5
# traning area 840
# 19.8
# traning area 840
# 20.0
# traning area 840
# 20.2
# traning area 840
# 20.5
# traning area 840
# 20.8
# traning area 840
# 21.0
# traning area 840
# 21.2
# traning area 840
# 21.5
# traning area 840
# 21.8
# traning area 840
# 22.0
# traning area 840
# 22.2
# traning area 840
# 22.5
# traning area 840
# 22.8
# traning area 840
# 23.0
# traning area 840
# 23.2
# traning area 840
# 23.5
# traning area 840
# 23.8
# traning area 840
# 24.0
# traning area 840
# 24.2
# traning area 840
# 24.5
# traning area 840
# 24.8
# traning area 840
# 25.0
# traning area 840
# 25.2
# traning area 840
# 25.5
# traning area 840
# 25.8
# traning area 840
# 26.0
# traning area 840
# 26.2
# traning area 840
# 26.5
# traning area 840
# 26.8
# traning area 840
# 27.0
# traning area 840
# 27.3
# traning area 840
# 27.5
# traning area 840
# 27.8
# traning area 840
# 28.0
# traning area 840
# 28.2
# traning area 840
# 28.5
# traning area 840
# 28.7
# traning area 840
# 29.0
# traning area 840
# 29.2
# traning area 840
# 29.5
# traning area 840
# 29.8
# traning area 840
# 30.0
# traning area 840
# 30.2
# traning area 840
# 30.5
# traning area 840
# 30.8
# traning area 840
# 31.0
# traning area 840
# 31.2
# traning area 840
# 31.5
# traning area 840
# 31.8
# traning area 840
# 32.0
# traning area 840
# 32.2
# traning area 840
# 32.5
# traning area 840
# 32.8
# traning area 840
# 33.0
# traning area 840
# 33.2
# traning area 840
# 33.5
# traning area 840
# 33.8
# traning area 840
# 34.0
# traning area 840
# 34.2
# traning area 840
# 34.5
# traning area 840
# 34.8
# traning area 840
# 35.0
# traning area 840
# 35.2
# traning area 840
# 35.5
# traning area 840
# 35.8
# traning area 840
# 36.0
# traning area 840
# 36.2
# traning area 840
# 36.5
# traning area 840
# 36.8
# traning area 840
# 37.0
# traning area 840
# 37.2
# traning area 840
# 37.5
# traning area 840
# 37.8
# traning area 840
# 38.0
# traning area 840
# 38.2
# traning area 840
# 38.5
# traning area 840
# 38.8
# traning area 840
# 39.0
# traning area 840
# 39.2
# traning area 840
# 39.5
# traning area 840
# 39.8
# traning area 840
# 40.0
# traning area 840
# 40.2
# traning area 840
# 40.5
# traning area 840
# 40.8
# traning area 840
# 41.0
# traning area 840
# 41.2
# traning area 840
# 41.5
# traning area 840
# 41.8
# traning area 840
# 42.0
# traning area 840
# 42.2
# traning area 840
# 42.5
# traning area 840
# 42.8
# traning area 840
# 43.0
# traning area 840
# 43.2
# traning area 840
# 43.5
# traning area 840
# 43.8
# traning area 840
# 44.0
# traning area 840
# 44.2
# traning area 840
# 44.5
# traning area 840
# 44.8
# traning area 840
# 45.0
# traning area 840
# 45.2
# traning area 840
# 45.5
# traning area 840
# 45.8
# traning area 840
# 46.0
# traning area 840
# 46.2
# traning area 840
# 46.5
# traning area 840
# 46.8
# traning area 840
# 47.0
# traning area 840
# 47.2
# traning area 840
# 47.5
# traning area 840
# 47.8
# traning area 840
# 48.0
# traning area 840
# 48.2
# traning area 840
# 48.5
# traning area 840
# 48.8
# traning area 840
# 49.0
# traning area 840
# 49.2
# traning area 840
# 49.5
# traning area 840
# 49.8
# traning area 840
# 50.0
# traning area 840
# 50.2
# traning area 840
# 50.5
# traning area 840
# 50.7
# traning area 840
# 51.0
# traning area 840
# 51.2
# traning area 840
# 51.5
# traning area 840
# 51.7
# traning area 840
# 52.0
# traning area 840
# 52.2
# traning area 840
# 52.5
# traning area 840
# 52.8
# traning area 840
# 53.0
# traning area 840
# 53.2
# traning area 840
# 53.5
# traning area 840
# 53.8
# traning area 840
# 54.0
# traning area 840
# 54.2
# traning area 840
# 54.5
# traning area 840
# 54.8
# traning area 840
# 55.0
# traning area 840
# 55.2
# traning area 840
# 55.5
# traning area 840
# 55.8
# traning area 840
# 56.0
# traning area 840
# 56.2
# traning area 840
# 56.5
# traning area 840
# 56.8
# traning area 840
# 57.0
# traning area 840
# 57.2
# traning area 840
# 57.5
# traning area 840
# 57.8
# traning area 840
# 58.0
# traning area 840
# 58.2
# traning area 840
# 58.5
# traning area 840
# 58.8
# traning area 840
# 59.0
# traning area 840
# 59.2
# traning area 840
# 59.5
# traning area 840
# 59.8
# traning area 840
# 60.0
# traning area 840
# 60.2
# traning area 840
# 60.5
# traning area 840
# 60.8
# traning area 840
# 61.0
# traning area 840
# 61.3
# traning area 840
# 61.5
# traning area 840
# 61.8
# traning area 840
# 62.0
# traning area 840
# 62.3
# traning area 840
# 62.5
# traning area 840
# 62.7
# traning area 840
# 63.0
# traning area 840
# 63.2
# traning area 840
# 63.5
# traning area 840
# 63.7
# traning area 840
# 64.0
# traning area 840
# 64.2
# traning area 840
# 64.5
# traning area 840
# 64.8
# traning area 840
# 65.0
# traning area 840
# 65.2
# traning area 840
# 65.5
# traning area 840
# 65.8
# traning area 840
# 66.0
# traning area 840
# 66.2
# traning area 840
# 66.5
# traning area 840
# 66.8
# traning area 840
# 67.0
# traning area 840
# 67.2
# traning area 840
# 67.5
# traning area 840
# 67.8
# traning area 840
# 68.0
# traning area 840
# 68.2
# traning area 840
# 68.5
# traning area 840
# 68.8
# traning area 840
# 69.0
# traning area 840
# 69.2
# traning area 840
# 69.5
# traning area 840
# 69.8
# traning area 840
# 70.0
# traning area 840
# 70.2
# traning area 840
# 70.5
# traning area 840
# 70.8
# traning area 840
# 71.0
# traning area 840
# 71.2
# traning area 840
# 71.5
# traning area 840
# 71.8
# traning area 840
# 72.0
# traning area 840
# 72.2
# traning area 840
# 72.5
# traning area 840
# 72.8
# traning area 840
# 73.0
# traning area 840
# 73.2
# traning area 840
# 73.5
# traning area 840
# 73.8
# traning area 840
# 74.0
# traning area 840
# 74.2
# traning area 840
# 74.5
# traning area 840
# 74.8
# traning area 840
# 75.0
# traning area 840
# 75.2
# traning area 840
# 75.5
# traning area 840
# 75.8
# traning area 840
# 76.0
# traning area 840
# 76.2
# traning area 840
# 76.5
# traning area 840
# 76.8
# traning area 840
# 77.0
# traning area 840
# 77.2
# traning area 840
# 77.5
# traning area 840
# 77.8
# traning area 840
# 78.0
# traning area 840
# 78.2
# traning area 840
# 78.5
# traning area 840
# 78.8
# traning area 840
# 79.0
# traning area 840
# 79.2
# traning area 840
# 79.5
# traning area 840
# 79.8
# traning area 840
# 80.0
# traning area 840
# 80.2
# traning area 840
# 80.5
# traning area 840
# 80.8
# traning area 840
# 81.0
# traning area 840
# 81.2
# traning area 840
# 81.5
# traning area 840
# 81.8
# traning area 840
# 82.0
# traning area 840
# 82.2
# traning area 840
# 82.5
# traning area 840
# 82.8
# traning area 840
# 83.0
# traning area 840
# 83.2
# traning area 840
# 83.5
# traning area 840
# 83.8
# traning area 840
# 84.0
# traning area 840
# 84.2
# traning area 840
# 84.5
# traning area 840
# 84.8
# traning area 840
# 85.0
# traning area 840
# 85.2
# traning area 840
# 85.5
# traning area 840
# 85.8
# traning area 840
# 86.0
# traning area 840
# 86.2
# traning area 840
# 86.5
# traning area 840
# 86.8
# traning area 840
# 87.0
# traning area 840
# 87.2
# traning area 840
# 87.5
# traning area 840
# 87.8
# traning area 840
# 88.0
# traning area 840
# 88.2
# traning area 840
# 88.5
# traning area 840
# 88.8
# traning area 840
# 89.0
# traning area 840
# 89.2
# traning area 840
# 89.5
# traning area 840
# 89.8
# traning area 840
# 90.0
# traning area 840
# 90.2
# traning area 840
# 90.5
# traning area 840
# 90.8
# traning area 840
# 91.0
# traning area 840
# 91.2
# traning area 840
# 91.5
# traning area 840
# 91.8
# traning area 840
# 92.0
# traning area 840
# 92.2
# traning area 840
# 92.5
# traning area 840
# 92.8
# traning area 840
# 93.0
# traning area 840
# 93.2
# traning area 840
# 93.5
# traning area 840
# 93.8
# traning area 840
# 94.0
# traning area 840
# 94.2
# traning area 840
# 94.5
# traning area 840
# 94.8
# traning area 840
# 95.0
# traning area 840
# 95.2
# traning area 840
# 95.5
# traning area 840
# 95.8
# traning area 840
# 96.0
# traning area 840
# 96.2
# traning area 840
# 96.5
# traning area 840
# 96.8
# traning area 840
# 97.0
# traning area 840
# 97.2
# traning area 840
# 97.5
# traning area 840
# 97.8
# traning area 840
# 98.0
# traning area 840
# 98.2
# traning area 840
# 98.5
# traning area 840
# 98.8
# traning area 840
# 99.0
# traning area 840
# 99.2
# traning area 840
# 99.5
# traning area 840
# 99.8

# %%
# %matplotlib ipympl
labels = {
    "x_label":"Velocity [knots]",
    "y_label":"Range [m]",
    "title": "All CFAR detections"

}
#data_fft_plot = cv2.GaussianBlur(np.abs(data_ma), (3, 3),sigmaX=1,sigmaY=1)
#data_fft_plot = ndimage.gaussian_filter(data_fft_plot,sigma=1,mode=mode)
#sns.set(rc={'figure.figsize':(20,15)})
test = np.sum(np.abs(cfar_median),axis=0)
plt.figure(figsize=(10,10))
print(np.shape(test))
rotated_img =20*np.log10(np.abs(test)) # We rotate the image so the x axis is the velocity
#rotated_img = test
#rotated_img = cv2.GaussianBlur(rotated_img, (3, 3),sigmaX=1,sigmaY=1)
plt.imshow(rotated_img,cmap="plasma", vmin=plot_min_doppler,vmax=plot_max_doppler)
#plt.imshow(rotated_img,cmap="plasma")
# rms = 10*np.log(np.sqrt(np.mean(np.abs(rotated_img[130:135,80:100])**2)))
# peak = 10*np.log(np.abs(rotated_img[137,87]))
# snr = peak-rms
# print("Peak:",peak)
# print("Side loab:", 10*np.log(np.abs(rotated_img[137,85])))
# print("RMS:",rms)
# print("SNR:",snr) 
#plt.yticks(np.linspace(0,256,9),labels=np.round(np.linspace(255*0.785277,0,9)),size =15)



#plt.xticks(np.linspace(0,256,7),labels=np.round(np.linspace(-0.127552440715*127,0.127552440715*127,7),2),size =15)
cbar  = plt.colorbar()
cbar.set_label('Mangnitude [dB]',fontdict = {'fontsize' : 20})
cbar.ax.tick_params(labelsize=15) 
plt.xlabel(labels["x_label"],fontdict = {'fontsize' : 20})
plt.ylabel(labels["y_label"],fontdict = {'fontsize' : 20})
plt.title(labels["title"],fontdict = {'fontsize' : 30})
plt.grid(False)
#plt.savefig("plots/munkholm/cfar_EMA_0_MTI_munkholm_with_window.svg",format="svg")
# Out:
# (256, 256)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
detections = np.sum(np.abs(cfar_median),axis=0)

detection_line = np.abs(detections[:157,87])

r = np.linspace(200,122,157)
r_squared =75/(r/122)**4

plt.plot(detection_line,label="Calculated SNR")

plt.plot(r_squared,label="Theoretical SNR decrease")

plt.legend()
plt.title("SNR vs theoretical decrease",size=25)
#plt.xticks(np.linspace(0,157,1),labels=np.round(np.linspace(-0.127552440715*127,0.127552440715*127,7),2),size=15)
plt.yticks(size=15)
plt.xlabel("range [m]",size=20)
plt.ylabel("SNR",size=20)
plt.tight_layout()
plt.xticks(np.linspace(0,156,9),labels=np.int16(np.linspace(200,156*0.785277,9)),size =15)
#plt.savefig("plots/SNR_vs_falloff.svg",format="svg")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # IO

# %%
cfar_IO= []
#SNR_array = []
#SNR_D_array = []
length_data_diff = len(data_diff[100:500])
for i,img in enumerate( data_diff[100:500]):
    cfar ,y,SNR = utils.CFAR_IO(img,10, 15, 0.000001,plot=False, iso_axis=True)
    cfar_IO.append(cfar)
    #SNR_array.append(SNR)
    #SNR_D_array.append(y)
    print(np.round(i/length_data_diff*100,1))
# Out:
# traning area 2160
# 0.0
# traning area 2160
# 0.2
# traning area 2160
# 0.5
# traning area 2160
# 0.8
# traning area 2160
# 1.0
# traning area 2160
# 1.2
# traning area 2160
# 1.5
# traning area 2160
# 1.8
# traning area 2160
# 2.0
# traning area 2160
# 2.2
# traning area 2160
# 2.5
# traning area 2160
# 2.8
# traning area 2160
# 3.0
# traning area 2160
# 3.2
# traning area 2160
# 3.5
# traning area 2160
# 3.8
# traning area 2160
# 4.0
# traning area 2160
# 4.2
# traning area 2160
# 4.5
# traning area 2160
# 4.8
# traning area 2160
# 5.0
# traning area 2160
# 5.2
# traning area 2160
# 5.5
# traning area 2160
# 5.8
# traning area 2160
# 6.0
# traning area 2160
# 6.2
# traning area 2160
# 6.5
# traning area 2160
# 6.8
# traning area 2160
# 7.0
# traning area 2160
# 7.2
# traning area 2160
# 7.5
# traning area 2160
# 7.8
# traning area 2160
# 8.0
# traning area 2160
# 8.2
# traning area 2160
# 8.5
# traning area 2160
# 8.8
# traning area 2160
# 9.0
# traning area 2160
# 9.2
# traning area 2160
# 9.5
# traning area 2160
# 9.8
# traning area 2160
# 10.0
# traning area 2160
# 10.2
# traning area 2160
# 10.5
# traning area 2160
# 10.8
# traning area 2160
# 11.0
# traning area 2160
# 11.2
# traning area 2160
# 11.5
# traning area 2160
# 11.8
# traning area 2160
# 12.0
# traning area 2160
# 12.2
# traning area 2160
# 12.5
# traning area 2160
# 12.8
# traning area 2160
# 13.0
# traning area 2160
# 13.2
# traning area 2160
# 13.5
# traning area 2160
# 13.8
# traning area 2160
# 14.0
# traning area 2160
# 14.2
# traning area 2160
# 14.5
# traning area 2160
# 14.8
# traning area 2160
# 15.0
# traning area 2160
# 15.2
# traning area 2160
# 15.5
# traning area 2160
# 15.8
# traning area 2160
# 16.0
# traning area 2160
# 16.2
# traning area 2160
# 16.5
# traning area 2160
# 16.8
# traning area 2160
# 17.0
# traning area 2160
# 17.2
# traning area 2160
# 17.5
# traning area 2160
# 17.8
# traning area 2160
# 18.0
# traning area 2160
# 18.2
# traning area 2160
# 18.5
# traning area 2160
# 18.8
# traning area 2160
# 19.0
# traning area 2160
# 19.2
# traning area 2160
# 19.5
# traning area 2160
# 19.8
# traning area 2160
# 20.0
# traning area 2160
# 20.2
# traning area 2160
# 20.5
# traning area 2160
# 20.8
# traning area 2160
# 21.0
# traning area 2160
# 21.2
# traning area 2160
# 21.5
# traning area 2160
# 21.8
# traning area 2160
# 22.0
# traning area 2160
# 22.2
# traning area 2160
# 22.5
# traning area 2160
# 22.8
# traning area 2160
# 23.0
# traning area 2160
# 23.2
# traning area 2160
# 23.5
# traning area 2160
# 23.8
# traning area 2160
# 24.0
# traning area 2160
# 24.2
# traning area 2160
# 24.5
# traning area 2160
# 24.8
# traning area 2160
# 25.0
# traning area 2160
# 25.2
# traning area 2160
# 25.5
# traning area 2160
# 25.8
# traning area 2160
# 26.0
# traning area 2160
# 26.2
# traning area 2160
# 26.5
# traning area 2160
# 26.8
# traning area 2160
# 27.0
# traning area 2160
# 27.3
# traning area 2160
# 27.5
# traning area 2160
# 27.8
# traning area 2160
# 28.0
# traning area 2160
# 28.2
# traning area 2160
# 28.5
# traning area 2160
# 28.7
# traning area 2160
# 29.0
# traning area 2160
# 29.2
# traning area 2160
# 29.5
# traning area 2160
# 29.8
# traning area 2160
# 30.0
# traning area 2160
# 30.2
# traning area 2160
# 30.5
# traning area 2160
# 30.8
# traning area 2160
# 31.0
# traning area 2160
# 31.2
# traning area 2160
# 31.5
# traning area 2160
# 31.8
# traning area 2160
# 32.0
# traning area 2160
# 32.2
# traning area 2160
# 32.5
# traning area 2160
# 32.8
# traning area 2160
# 33.0
# traning area 2160
# 33.2
# traning area 2160
# 33.5
# traning area 2160
# 33.8
# traning area 2160
# 34.0
# traning area 2160
# 34.2
# traning area 2160
# 34.5
# traning area 2160
# 34.8
# traning area 2160
# 35.0
# traning area 2160
# 35.2
# traning area 2160
# 35.5
# traning area 2160
# 35.8
# traning area 2160
# 36.0
# traning area 2160
# 36.2
# traning area 2160
# 36.5
# traning area 2160
# 36.8
# traning area 2160
# 37.0
# traning area 2160
# 37.2
# traning area 2160
# 37.5
# traning area 2160
# 37.8
# traning area 2160
# 38.0
# traning area 2160
# 38.2
# traning area 2160
# 38.5
# traning area 2160
# 38.8
# traning area 2160
# 39.0
# traning area 2160
# 39.2
# traning area 2160
# 39.5
# traning area 2160
# 39.8
# traning area 2160
# 40.0
# traning area 2160
# 40.2
# traning area 2160
# 40.5
# traning area 2160
# 40.8
# traning area 2160
# 41.0
# traning area 2160
# 41.2
# traning area 2160
# 41.5
# traning area 2160
# 41.8
# traning area 2160
# 42.0
# traning area 2160
# 42.2
# traning area 2160
# 42.5
# traning area 2160
# 42.8
# traning area 2160
# 43.0
# traning area 2160
# 43.2
# traning area 2160
# 43.5
# traning area 2160
# 43.8
# traning area 2160
# 44.0
# traning area 2160
# 44.2
# traning area 2160
# 44.5
# traning area 2160
# 44.8
# traning area 2160
# 45.0
# traning area 2160
# 45.2
# traning area 2160
# 45.5
# traning area 2160
# 45.8
# traning area 2160
# 46.0
# traning area 2160
# 46.2
# traning area 2160
# 46.5
# traning area 2160
# 46.8
# traning area 2160
# 47.0
# traning area 2160
# 47.2
# traning area 2160
# 47.5
# traning area 2160
# 47.8
# traning area 2160
# 48.0
# traning area 2160
# 48.2
# traning area 2160
# 48.5
# traning area 2160
# 48.8
# traning area 2160
# 49.0
# traning area 2160
# 49.2
# traning area 2160
# 49.5
# traning area 2160
# 49.8
# traning area 2160
# 50.0
# traning area 2160
# 50.2
# traning area 2160
# 50.5
# traning area 2160
# 50.7
# traning area 2160
# 51.0
# traning area 2160
# 51.2
# traning area 2160
# 51.5
# traning area 2160
# 51.7
# traning area 2160
# 52.0
# traning area 2160
# 52.2
# traning area 2160
# 52.5
# traning area 2160
# 52.8
# traning area 2160
# 53.0
# traning area 2160
# 53.2
# traning area 2160
# 53.5
# traning area 2160
# 53.8
# traning area 2160
# 54.0
# traning area 2160
# 54.2
# traning area 2160
# 54.5
# traning area 2160
# 54.8
# traning area 2160
# 55.0
# traning area 2160
# 55.2
# traning area 2160
# 55.5
# traning area 2160
# 55.8
# traning area 2160
# 56.0
# traning area 2160
# 56.2
# traning area 2160
# 56.5
# traning area 2160
# 56.8
# traning area 2160
# 57.0
# traning area 2160
# 57.2
# traning area 2160
# 57.5
# traning area 2160
# 57.8
# traning area 2160
# 58.0
# traning area 2160
# 58.2
# traning area 2160
# 58.5
# traning area 2160
# 58.8
# traning area 2160
# 59.0
# traning area 2160
# 59.2
# traning area 2160
# 59.5
# traning area 2160
# 59.8
# traning area 2160
# 60.0
# traning area 2160
# 60.2
# traning area 2160
# 60.5
# traning area 2160
# 60.8
# traning area 2160
# 61.0
# traning area 2160
# 61.3
# traning area 2160
# 61.5
# traning area 2160
# 61.8
# traning area 2160
# 62.0
# traning area 2160
# 62.3
# traning area 2160
# 62.5
# traning area 2160
# 62.7
# traning area 2160
# 63.0
# traning area 2160
# 63.2
# traning area 2160
# 63.5
# traning area 2160
# 63.7
# traning area 2160
# 64.0
# traning area 2160
# 64.2
# traning area 2160
# 64.5
# traning area 2160
# 64.8
# traning area 2160
# 65.0
# traning area 2160
# 65.2
# traning area 2160
# 65.5
# traning area 2160
# 65.8
# traning area 2160
# 66.0
# traning area 2160
# 66.2
# traning area 2160
# 66.5
# traning area 2160
# 66.8
# traning area 2160
# 67.0
# traning area 2160
# 67.2
# traning area 2160
# 67.5
# traning area 2160
# 67.8
# traning area 2160
# 68.0
# traning area 2160
# 68.2
# traning area 2160
# 68.5
# traning area 2160
# 68.8
# traning area 2160
# 69.0
# traning area 2160
# 69.2
# traning area 2160
# 69.5
# traning area 2160
# 69.8
# traning area 2160
# 70.0
# traning area 2160
# 70.2
# traning area 2160
# 70.5
# traning area 2160
# 70.8
# traning area 2160
# 71.0
# traning area 2160
# 71.2
# traning area 2160
# 71.5
# traning area 2160
# 71.8
# traning area 2160
# 72.0
# traning area 2160
# 72.2
# traning area 2160
# 72.5
# traning area 2160
# 72.8
# traning area 2160
# 73.0
# traning area 2160
# 73.2
# traning area 2160
# 73.5
# traning area 2160
# 73.8
# traning area 2160
# 74.0
# traning area 2160
# 74.2
# traning area 2160
# 74.5
# traning area 2160
# 74.8
# traning area 2160
# 75.0
# traning area 2160
# 75.2
# traning area 2160
# 75.5
# traning area 2160
# 75.8
# traning area 2160
# 76.0
# traning area 2160
# 76.2
# traning area 2160
# 76.5
# traning area 2160
# 76.8
# traning area 2160
# 77.0
# traning area 2160
# 77.2
# traning area 2160
# 77.5
# traning area 2160
# 77.8
# traning area 2160
# 78.0
# traning area 2160
# 78.2
# traning area 2160
# 78.5
# traning area 2160
# 78.8
# traning area 2160
# 79.0
# traning area 2160
# 79.2
# traning area 2160
# 79.5
# traning area 2160
# 79.8
# traning area 2160
# 80.0
# traning area 2160
# 80.2
# traning area 2160
# 80.5
# traning area 2160
# 80.8
# traning area 2160
# 81.0
# traning area 2160
# 81.2
# traning area 2160
# 81.5
# traning area 2160
# 81.8
# traning area 2160
# 82.0
# traning area 2160
# 82.2
# traning area 2160
# 82.5
# traning area 2160
# 82.8
# traning area 2160
# 83.0
# traning area 2160
# 83.2
# traning area 2160
# 83.5
# traning area 2160
# 83.8
# traning area 2160
# 84.0
# traning area 2160
# 84.2
# traning area 2160
# 84.5
# traning area 2160
# 84.8
# traning area 2160
# 85.0
# traning area 2160
# 85.2
# traning area 2160
# 85.5
# traning area 2160
# 85.8
# traning area 2160
# 86.0
# traning area 2160
# 86.2
# traning area 2160
# 86.5
# traning area 2160
# 86.8
# traning area 2160
# 87.0
# traning area 2160
# 87.2
# traning area 2160
# 87.5
# traning area 2160
# 87.8
# traning area 2160
# 88.0
# traning area 2160
# 88.2
# traning area 2160
# 88.5
# traning area 2160
# 88.8
# traning area 2160
# 89.0
# traning area 2160
# 89.2
# traning area 2160
# 89.5
# traning area 2160
# 89.8
# traning area 2160
# 90.0
# traning area 2160
# 90.2
# traning area 2160
# 90.5
# traning area 2160
# 90.8
# traning area 2160
# 91.0
# traning area 2160
# 91.2
# traning area 2160
# 91.5
# traning area 2160
# 91.8
# traning area 2160
# 92.0
# traning area 2160
# 92.2
# traning area 2160
# 92.5
# traning area 2160
# 92.8
# traning area 2160
# 93.0
# traning area 2160
# 93.2
# traning area 2160
# 93.5
# traning area 2160
# 93.8
# traning area 2160
# 94.0
# traning area 2160
# 94.2
# traning area 2160
# 94.5
# traning area 2160
# 94.8
# traning area 2160
# 95.0
# traning area 2160
# 95.2
# traning area 2160
# 95.5
# traning area 2160
# 95.8
# traning area 2160
# 96.0
# traning area 2160
# 96.2
# traning area 2160
# 96.5
# traning area 2160
# 96.8
# traning area 2160
# 97.0
# traning area 2160
# 97.2
# traning area 2160
# 97.5
# traning area 2160
# 97.8
# traning area 2160
# 98.0
# traning area 2160
# 98.2
# traning area 2160
# 98.5
# traning area 2160
# 98.8
# traning area 2160
# 99.0
# traning area 2160
# 99.2
# traning area 2160
# 99.5
# traning area 2160
# 99.8

# %%
# %matplotlib ipympl
labels = {
    "x_label":"Velocity [knots]",
    "y_label":"Range [m]",
    "title": "All CFAR detections"

}
#data_fft_plot = cv2.GaussianBlur(np.abs(data_ma), (3, 3),sigmaX=1,sigmaY=1)
#data_fft_plot = ndimage.gaussian_filter(data_fft_plot,sigma=1,mode=mode)
#sns.set(rc={'figure.figsize':(20,15)})
test = np.sum(np.abs(cfar_IO),axis=0)
test[test>0]=1
plt.figure(figsize=(10,10))
print(np.shape(test))
rotated_img =np.abs(test) # We rotate the image so the x axis is the velocity
#rotated_img = test
#rotated_img = cv2.GaussianBlur(rotated_img, (3, 3),sigmaX=1,sigmaY=1)
#plt.imshow(rotated_img,cmap="plasma", vmin=-10,vmax=50)
plt.imshow(rotated_img,cmap="plasma")
# rms = 10*np.log(np.sqrt(np.mean(np.abs(rotated_img[130:135,80:100])**2)))
# peak = 10*np.log(np.abs(rotated_img[137,87]))
# snr = peak-rms
# print("Peak:",peak)
# print("Side loab:", 10*np.log(np.abs(rotated_img[137,85])))
# print("RMS:",rms)
# print("SNR:",snr) 
plt.yticks(np.linspace(0,256,9),labels=np.round(np.linspace(255*0.785277,0,9)),size =15)



plt.xticks(np.linspace(0,256,7),labels=np.round(np.linspace(-0.127552440715*127,0.127552440715*127,7),2),size =15)

plt.xlabel(labels["x_label"],fontdict = {'fontsize' : 20})
plt.ylabel(labels["y_label"],fontdict = {'fontsize' : 20})
plt.title(labels["title"],fontdict = {'fontsize' : 30})
plt.grid(False)
plt.savefig("plots/elfryd_IO.svg",format="svg")
# Out:
# (256, 256)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
